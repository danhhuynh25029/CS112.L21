# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1d-hvE9jq7Rb1TTLJ5Lfuyp3u-QjGbxuK?usp=sharing)

# %% [markdown]
# ## CS112.L21-N10
# 1. 19521322 Huỳnh Ngọc Công Danh
#
# 2. 19521917 Nguyễn Ngọc Thái Nguyên
#
# 3. 19521836 Lê Quang Minh
#
# 4. 19521858 Võ Tuấn Minh
#
# ## 1.Abstraction(Trừu tượng)
# Thây 1 số bất kì trong chuỗi số  n sao cho sao cho số đó chia hết cho 3 và lớn nhất
#
# Điều kiện:
#
# n là sô nguyên,n < 100(chữ số) và không chứa các số 0 vô nghĩa
# ## 2.Pattern Recognition (NHẬN DIỆN KHUÔN MẪU)
# Kỹ thuật : Vét cạn
# ## 3. ALGORITHM DESIGNED (THIẾT KẾ THUẬT TOÁN)
# Mã giả:
#
# SET n TO INPUT().strip()
#
# SET length TO len(n)
#
# SET n TO int(n)
#
# SET arr TO []
#
# FOR i IN range(length):
#
#     SET t TO n%10
#
#     arr.append(t)
#
#     SET n TO n//10
#
# SET arr TO arr[::-1]
#
# SET i TO 9
#
# SET j TO 0
#
# DEFINE FUNCTION reduce(arr):
#
#     SET i TO 9
#
#     SET j TO length -1
#
#     WHILE i > 0:
#
#         IF arr[j] > i and (sum(arr) - arr[j] + i) % 3 EQUALS 0:
#
#             SET arr[j] TO i
#
#             OUTPUT(*arr,sep="")
#
#             break
#
#         IF i EQUALS 1:
#
#             IF j > 1:
#
#                 OUTPUT(j)
#
#                 j -= 1
#
#             SET i TO 9
#
#             continue
#
#         i -= 1
#
#
#
# WHILE i > 0:
#
#     IF arr[j] < i and (sum(arr) - arr[j] + i) % 3 EQUALS 0:
#
#         SET arr[j] TO i
#
#         OUTPUT(*arr,sep="")
#
#         break
#
#     IF i EQUALS 1:
#
#         IF j EQUALS length - 1:
#
#             reduce(arr)
#
#             break
#
#         IF j < length-1:
#
#             j += 1
#
#         SET i TO 9
#
#         continue
#
#     i -= 1
# ## 4.Độ phức tạp thuật toán
# Độ phức tạp thuật toán : O(log(n))
# ## 5.Code mẫu

# %%
n = input().strip()
length = len(n)
n = int(n)
arr = []
for i in range(length):
    t = n%10
    arr.append(t)
    n = n//10
arr = arr[::-1]
i = 9
j = 0
def reduce(arr):
    i = 9
    j = length -1
    while i > 0:
        if arr[j] > i and (sum(arr) - arr[j] + i) % 3 == 0:
            arr[j] = i
            print(*arr,sep="")
            break
        if i == 1:
            if j > 1:
                print(j)
                j -= 1
            i = 9
            continue
        i -= 1

while i > 0:
    if arr[j] < i and (sum(arr) - arr[j] + i) % 3 == 0:
        arr[j] = i
        print(*arr,sep="")
        break
    if i == 1:
        if j == length - 1:
            reduce(arr)
            break
        if j < length-1:
            j += 1
        i = 9
        continue
    i -= 1
# Out:
# 123
# 723
