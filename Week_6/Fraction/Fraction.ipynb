# %% [markdown]
# ## CS112.L21-N10
# 1. 19521322 Huỳnh Ngọc Công Danh
#
# 2. 19521917 Nguyễn Ngọc Thái Nguyên
#
# 3. 19521836 Lê Quang Minh
#
# 4. 19521858 Võ Tuấn Minh
#
# ## 1.Abstraction(Trừu tượng)
# Đếm số bước để biến dổi phân số
# $$
# \frac{a}{b} = \frac{c}{d} \\
# $$
# Với mỗi bước biến đổi thì giá trị a,b tăng lên 1
#
# Điều kiện:
# $$
# 0 < a < b ≤10^5,0 < c < d ≤ 10^5 \\
# \frac{a}{b} ≠ \frac{c}{d}
# $$
# a và b là nguyên tố cùng nhau,c và d là nguyên tố cùng nhau
# ## 2.Pattern Recognition (NHẬN DIỆN KHUÔN MẪU)
# $$
# \frac{a+x}{b+x} = \frac{c}{d} \\
# \Rightarrow x = \frac{b*c - a*d}{d-c}  \\
# $$
# Từ đó ta tìm được x là con số cộng vào để được phân số
# sử dụng vòng lặp để tìm số bước chính xác để biến đổi phân số
# ## 3. ALGORITHM DESIGNED (THIẾT KẾ THUẬT TOÁN)
# SET a TO int(INPUT())
#
# SET b TO int(INPUT())
#
# SET c TO int(INPUT())
#
# SET d TO int(INPUT())
#
# DEFINE FUNCTION gcd(a,b):
#
#     IF b EQUALS 0 :
#
#         RETURN a
#
#     ELSE:
#
#         RETURN gcd(b,a%b)
#
# DEFINE FUNCTION find(a,b,c,d):
#
#     RETURN (b*c - a*d)/(d-c)
#
# SET tmp TO int(find(a,b,c,d))
#
# IF tmp >= 0:
#
#     FOR i IN range(1,(tmp)+1):
#
#         a +=1
#
#         b += 1
#
#         SET ucln TO gcd(a,b)
#
#         SET a TO a//ucln
#
#         SET b TO b//ucln
#
#         IF a EQUALS c and b EQUALS d:
#
#             OUTPUT(i)
#
#             break
#
#         tmp -= 1
#
#     IF tmp EQUALS 0:
#
#         OUTPUT(0)
#
# ELSE:
#
#     OUTPUT(0)
#
# ## 4.Dộ phức tạp thuật toán
# Độ phức tạp :
#
# ## 5.Code mẫu

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
def gcd(a,b):
    if b == 0 :
        return a
    else:
        return gcd(b,a%b)
def find(a,b,c,d):
    return (b*c - a*d)/(d-c)
tmp = int(find(a,b,c,d))
if tmp >= 0:
    for i in range(1,(tmp)+1):
        a +=1
        b += 1
        ucln = gcd(a,b)
        a = a//ucln
        b = b//ucln
        if a == c and b == d:
            print(i)
            break
        tmp -= 1
    if tmp == 0:
        print(0)
else:
    print(0)
# Out:
# 1
# 6
# 2
# 3
# 5
